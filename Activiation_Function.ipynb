# %% [markdown]
# <a href="https://colab.research.google.com/github/Dosubeen630/AI-project/blob/main/%08Activiation_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def sigmoid(x) :
    return 1/ (1+ np.exp(-x))
    # 시그모이드 함수

# %%
x= np.arange(-5,5,0.1)
y= sigmoid(x)
x.shape, y.shape
# Out:
# ((100,), (100,))

# %%
def spines() :
    ax = plt.gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_position(('data',0))
    ax.spines['left'].set_position(('data',0))

    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

# %%
plt.plot(x,y)
plt.grid()
spines()
plt.show()

# %%
x = np.arange(-5,5,0.1)
y = np.tanh(x)

# %%
plt.plot(x,y)
plt.grid()
spines()
plt.show()

# %%
def relu(x) :
    return np.maximum(0,x)

# %%
x = np.arange(-5,5,0.1)
y = relu(x)

plt.plot(x,y)
plt.grid()
spines()
plt.show()

# %%
def softmax(x) :
    return np.exp(x) / np.sum(np.exp(x))

# %%
x =  np.arange(1,5)
y =  softmax(x)
y
# Out:
# array([0.0320586 , 0.08714432, 0.23688282, 0.64391426])

# %%
np.sum(y)
# Out:
# 1.0

# %%
ratio = y
labels = y
plt.pie(ratio, labels=labels, shadow=True, startangle=90)
plt.show()
